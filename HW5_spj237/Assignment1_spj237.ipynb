# %%
import os
puidata = os.getenv("PUIDATA")
print(puidata)
# Out:
# /nfshome/spj237/PUIdata

# %%
from __future__ import print_function
import pandas as pd

# %%
mn = pd.read_csv("%s/MN_18v1.csv"%os.getenv("PUIDATA"))
bk = pd.read_csv("%s/BK_18v1.csv"%os.getenv("PUIDATA"))
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (20,23,24,26,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (19,20,22,23,24,25,26,64,65,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mn.head(10)
# Out:
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      MN      1   10  101     5.0  1011.0         2.0      1.0  10004.0
# 1      MN      1  101  101     1.0  1001.0         2.0      1.0  10004.0
# 2      MN      1  201  101     1.0  1000.0         2.0      1.0  10004.0
# 3      MN      1  301  101     NaN     NaN         2.0      1.0  10004.0
# 4      MN      1  401  101     NaN     NaN         2.0      1.0  10004.0
# 5      MN      2    1  101     9.0  1025.0         2.0      1.0  10004.0
# 6      MN      2    2  101     9.0  1025.0         2.0      1.0  10004.0
# 7      MN      2    3  101     9.0     NaN         2.0      1.0  10004.0
# 8      MN      2   23  101     9.0  1025.0         2.0      1.0  10004.0
# 9      MN      3    1  101   319.0  1000.0         2.0      1.0  10004.0
#
#   FireComp   ...    ZMCode   Sanborn   TaxMap  EDesigNum        APPBBL  \
# 0     E007   ...         Y   199 999  10101.0        NaN  0.000000e+00
# ...

# %%
bk.head(10)
# Out:
#   Borough  Block   Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      BK      1     1  302    21.0     NaN        13.0     33.0  11201.0
# 1      BK      1    50  302    21.0  2000.0        13.0     33.0  11201.0
# 2      BK      1  7501  302    21.0  2000.0        13.0     33.0  11201.0
# 3      BK      3     1  302    21.0  3002.0        13.0     33.0  11201.0
# 4      BK      3     5  302    21.0     NaN        13.0     33.0  11201.0
# 5      BK      3    35  302     NaN     NaN         NaN      NaN      NaN
# 6      BK      5     1  302    21.0  3001.0        13.0     33.0  11201.0
# 7      BK      5     8  302    21.0     NaN        13.0     33.0  11201.0
# 8      BK      6     1  302    21.0  3000.0        13.0     33.0  11201.0
# 9      BK      6    10  302    21.0     NaN        13.0     33.0  11201.0
#
#   FireComp   ...    ZMCode  Sanborn   TaxMap  EDesigNum        APPBBL  \
# 0     L118   ...       NaN  302 007  30101.0        NaN  3.000010e+09
# ...

# %%
mn.columns
# Out:
# Index(['Borough', 'Block', 'Lot', 'CD', 'CT2010', 'CB2010', 'SchoolDist',
#        'Council', 'ZipCode', 'FireComp', 'PolicePrct', 'HealthCenterDistrict',
#        'HealthArea', 'SanitBoro', 'SanitDistrict', 'SanitSub', 'Address',
#        'ZoneDist1', 'ZoneDist2', 'ZoneDist3', 'ZoneDist4', 'Overlay1',
#        'Overlay2', 'SPDist1', 'SPDist2', 'SPDist3', 'LtdHeight', 'SplitZone',
#        'BldgClass', 'LandUse', 'Easements', 'OwnerType', 'OwnerName',
#        'LotArea', 'BldgArea', 'ComArea', 'ResArea', 'OfficeArea', 'RetailArea',
#        'GarageArea', 'StrgeArea', 'FactryArea', 'OtherArea', 'AreaSource',
#        'NumBldgs', 'NumFloors', 'UnitsRes', 'UnitsTotal', 'LotFront',
#        'LotDepth', 'BldgFront', 'BldgDepth', 'Ext', 'ProxCode', 'IrrLotCode',
#        'LotType', 'BsmtCode', 'AssessLand', 'AssessTot', 'ExemptLand',
#        'ExemptTot', 'YearBuilt', 'YearAlter1', 'YearAlter2', 'HistDist',
#        'Landmark', 'BuiltFAR', 'ResidFAR', 'CommFAR', 'FacilFAR', 'BoroCode',
# ...

# %%
bk.columns
# Out:
# Index(['Borough', 'Block', 'Lot', 'CD', 'CT2010', 'CB2010', 'SchoolDist',
#        'Council', 'ZipCode', 'FireComp', 'PolicePrct', 'HealthCenterDistrict',
#        'HealthArea', 'SanitBoro', 'SanitDistrict', 'SanitSub', 'Address',
#        'ZoneDist1', 'ZoneDist2', 'ZoneDist3', 'ZoneDist4', 'Overlay1',
#        'Overlay2', 'SPDist1', 'SPDist2', 'SPDist3', 'LtdHeight', 'SplitZone',
#        'BldgClass', 'LandUse', 'Easements', 'OwnerType', 'OwnerName',
#        'LotArea', 'BldgArea', 'ComArea', 'ResArea', 'OfficeArea', 'RetailArea',
#        'GarageArea', 'StrgeArea', 'FactryArea', 'OtherArea', 'AreaSource',
#        'NumBldgs', 'NumFloors', 'UnitsRes', 'UnitsTotal', 'LotFront',
#        'LotDepth', 'BldgFront', 'BldgDepth', 'Ext', 'ProxCode', 'IrrLotCode',
#        'LotType', 'BsmtCode', 'AssessLand', 'AssessTot', 'ExemptLand',
#        'ExemptTot', 'YearBuilt', 'YearAlter1', 'YearAlter2', 'HistDist',
#        'Landmark', 'BuiltFAR', 'ResidFAR', 'CommFAR', 'FacilFAR', 'BoroCode',
# ...

# %%
mn.drop(['Borough', 'Block', 'Lot', 'CD', 'CT2010', 'CB2010', 'SchoolDist',
       'Council', 'FireComp', 'PolicePrct', 'HealthCenterDistrict',
       'HealthArea', 'SanitBoro', 'SanitDistrict', 'SanitSub', 'Address'], axis=1, inplace=True)

# %%
mn.drop(['ZoneDist1', 'ZoneDist2', 'ZoneDist3', 'ZoneDist4', 'Overlay1',
       'Overlay2', 'SPDist1', 'SPDist2', 'SPDist3', 'LtdHeight', 'SplitZone',
       'BldgClass', 'Easements', 'OwnerType', 'OwnerName',
       'LotArea', 'BldgArea', 'ComArea', 'ResArea', 'OfficeArea', 'RetailArea',
       'GarageArea', 'StrgeArea', 'FactryArea', 'OtherArea', 'AreaSource',], axis=1, inplace=True)

# %%
mn.drop(['NumBldgs', 'NumFloors', 'UnitsRes', 'UnitsTotal', 'LotFront',
       'LotDepth', 'BldgFront', 'BldgDepth', 'Ext', 'ProxCode', 'IrrLotCode',
       'LotType', 'BsmtCode', 'AssessLand', 'AssessTot', 'ExemptLand',
       'ExemptTot', 'YearBuilt', 'YearAlter1', 'YearAlter2', 'HistDist',
       'Landmark', 'BuiltFAR', 'ResidFAR', 'CommFAR', 'FacilFAR', 'BoroCode'], axis=1, inplace=True)

# %%
mn.drop(['BBL'], axis=1, inplace=True)

# %%
mn.drop(['CondoNo', 'Tract2010', 'XCoord', 'YCoord', 'ZoneMap', 'ZMCode',
       'Sanborn', 'TaxMap', 'EDesigNum', 'APPBBL', 'APPDate', 'PLUTOMapID','Version'], axis=1, inplace=True)

# %%
mn.drop(['FIRM07_Flag'], axis=1, inplace=True)

# %%
mn.drop(['PFIRM15_Flag'], axis=1, inplace=True)

# %%
mn.head()
# Out:
#    ZipCode  LandUse
# 0  10004.0      8.0
# 1  10004.0      8.0
# 2  10004.0      NaN
# 3  10004.0      7.0
# 4  10004.0      7.0

# %%
bk.drop(['Borough', 'Block', 'Lot', 'CD', 'CT2010', 'CB2010', 'SchoolDist',
       'Council', 'FireComp', 'PolicePrct', 'HealthCenterDistrict',
       'HealthArea', 'SanitBoro', 'SanitDistrict', 'SanitSub', 'Address',
       'ZoneDist1', 'ZoneDist2', 'ZoneDist3', 'ZoneDist4', 'Overlay1',
       'Overlay2', 'SPDist1', 'SPDist2', 'SPDist3', 'LtdHeight', 'SplitZone',
       'BldgClass', 'Easements', 'OwnerType', 'OwnerName',
       'LotArea', 'BldgArea', 'ComArea', 'ResArea', 'OfficeArea', 'RetailArea',
       'GarageArea', 'StrgeArea', 'FactryArea', 'OtherArea', 'AreaSource',
       'NumBldgs', 'NumFloors', 'UnitsRes', 'UnitsTotal', 'LotFront',
       'LotDepth', 'BldgFront', 'BldgDepth', 'Ext', 'ProxCode', 'IrrLotCode',
       'LotType', 'BsmtCode', 'AssessLand', 'AssessTot', 'ExemptLand',
       'ExemptTot', 'YearBuilt', 'YearAlter1', 'YearAlter2', 'HistDist',
       'Landmark', 'BuiltFAR', 'ResidFAR', 'CommFAR', 'FacilFAR', 'BoroCode',
       'BBL', 'CondoNo', 'Tract2010', 'XCoord', 'YCoord', 'ZoneMap', 'ZMCode',
       'Sanborn', 'TaxMap', 'EDesigNum', 'APPBBL', 'APPDate', 'PLUTOMapID',
       'FIRM07_FLAG', 'PFIRM15_FLAG', 'Version'], axis=1, inplace=True)

# %%
bk.head()
# Out:
#    ZipCode  LandUse
# 0  11201.0     11.0
# 1  11201.0      5.0
# 2  11201.0      4.0
# 3  11201.0      7.0
# 4  11201.0      7.0

# %%
mn.dtypes
# Out:
# ZipCode    float64
# LandUse    float64
# dtype: object

# %%
mngroup = mn.groupby('LandUse').count()
mngroup = mngroup.reset_index()
mngroup
# Out:
#     LandUse  ZipCode
# 0       1.0     4019
# 1       2.0    16246
# 2       3.0     4881
# 3       4.0     7238
# 4       5.0     4465
# 5       6.0      726
# 6       7.0      386
# 7       8.0     2456
# 8       9.0      434
# 9      10.0      679
# 10     11.0     1199

# %%
bkgroup = bk.groupby('LandUse').count()
bkgroup = bkgroup.reset_index()

# %%
mngroup.columns
# Out:
# Index(['LandUse', 'ZipCode'], dtype='object')

# %%
bkgroup.columns
# Out:
# Index(['LandUse', 'ZipCode'], dtype='object')

# %%
mngroup.dtypes
# Out:
# LandUse    float64
# ZipCode      int64
# dtype: object

# %%
mngroup['LandUse'] = mngroup.LandUse.astype(int)
#https://www.youtube.com/watch?v=V0AWyzVMf54&t=131s

# %%
bkgroup['LandUse'] = bkgroup.LandUse.astype(int)

# %%
mngroup
# Out:
#     LandUse  ZipCode
# 0         1     4019
# 1         2    16246
# 2         3     4881
# 3         4     7238
# 4         5     4465
# 5         6      726
# 6         7      386
# 7         8     2456
# 8         9      434
# 9        10      679
# 10       11     1199

# %%
bkgroup
# Out:
#     LandUse  ZipCode
# 0         1   156271
# 1         2    66358
# 2         3     3437
# 3         4    22515
# 4         5     5743
# 5         6     4434
# 6         7     1040
# 7         8     4330
# 8         9      872
# 9        10     4229
# 10       11     6298

# %%
merged = pd.merge(mngroup, bkgroup, on='LandUse')
merged
#https://www.youtube.com/watch?v=h4hOPGo4UVU&t=349s
# Out:
#     LandUse  ZipCode_x  ZipCode_y
# 0         1       4019     156271
# 1         2      16246      66358
# 2         3       4881       3437
# 3         4       7238      22515
# 4         5       4465       5743
# 5         6        726       4434
# 6         7        386       1040
# 7         8       2456       4330
# 8         9        434        872
# 9        10        679       4229
# 10       11       1199       6298

# %%
merged = merged.rename(index=str, columns={'ZipCode_x': 'mn', 'ZipCode_y':'bk'})
merged
#https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html
# Out:
#     LandUse     mn      bk
# 0         1   4019  156271
# 1         2  16246   66358
# 2         3   4881    3437
# 3         4   7238   22515
# 4         5   4465    5743
# 5         6    726    4434
# 6         7    386    1040
# 7         8   2456    4330
# 8         9    434     872
# 9        10    679    4229
# 10       11   1199    6298

# %%
dictionary = {1:'One &Two Family Buildings', 2:'Multi-Family Walk-Up Buildings', 3:'Multi-Family Elevator Buildings',
             4:'Mixed Residential & Commercial Buildings', 5:'Commercial & Office Buildings',
             6:'Industrial & Manufacturing', 7:'Transportation & Utility', 8:'Public Facilities & Institutions',
             9:'Open Space & Outdoor Recreation', 10:'Parking Facilities', 11:'Vacant Land'}

# %%
merged['LandUse'] = merged['LandUse'].map(dictionary)
#https://stackoverflow.com/questions/43367700/python-dataframe-replace-values-using-dictionary-convert-nan-if-not-in-diction?rq=1

# %%
merged
# Out:
#                                      LandUse     mn      bk
# 0                  One &Two Family Buildings   4019  156271
# 1             Multi-Family Walk-Up Buildings  16246   66358
# 2            Multi-Family Elevator Buildings   4881    3437
# 3   Mixed Residential & Commercial Buildings   7238   22515
# 4              Commercial & Office Buildings   4465    5743
# 5                 Industrial & Manufacturing    726    4434
# 6                   Transportation & Utility    386    1040
# 7           Public Facilities & Institutions   2456    4330
# 8            Open Space & Outdoor Recreation    434     872
# 9                         Parking Facilities    679    4229
# 10                               Vacant Land   1199    6298

# %%
r = merged.mn/merged.bk

# %%
merged['luratio'] = r
merged
# Out:
#                                      LandUse     mn      bk   luratio
# 0                  One &Two Family Buildings   4019  156271  0.025718
# 1             Multi-Family Walk-Up Buildings  16246   66358  0.244824
# 2            Multi-Family Elevator Buildings   4881    3437  1.420134
# 3   Mixed Residential & Commercial Buildings   7238   22515  0.321475
# 4              Commercial & Office Buildings   4465    5743  0.777468
# 5                 Industrial & Manufacturing    726    4434  0.163735
# 6                   Transportation & Utility    386    1040  0.371154
# 7           Public Facilities & Institutions   2456    4330  0.567206
# 8            Open Space & Outdoor Recreation    434     872  0.497706
# 9                         Parking Facilities    679    4229  0.160558
# 10                               Vacant Land   1199    6298  0.190378

# %%
#w = merged.luratio > 1

# %%
#merged['Manhattan wins'] = w
#merged

# %%
#Alternative method:
def Manhattan_wins2 (check):
    if check['luratio'] > 1 :
        return 'True'
    else:
        return 'False'
merged['Manhattan Wins'] = merged.apply(lambda check: Manhattan_wins2 (check), axis=1)
#https://stackoverflow.com/questions/26886653/pandas-create-new-column-based-on-values-from-other-columns

# %%
merged
# Out:
#                                      LandUse     mn      bk   luratio  \
# 0                  One &Two Family Buildings   4019  156271  0.025718
# 1             Multi-Family Walk-Up Buildings  16246   66358  0.244824
# 2            Multi-Family Elevator Buildings   4881    3437  1.420134
# 3   Mixed Residential & Commercial Buildings   7238   22515  0.321475
# 4              Commercial & Office Buildings   4465    5743  0.777468
# 5                 Industrial & Manufacturing    726    4434  0.163735
# 6                   Transportation & Utility    386    1040  0.371154
# 7           Public Facilities & Institutions   2456    4330  0.567206
# 8            Open Space & Outdoor Recreation    434     872  0.497706
# 9                         Parking Facilities    679    4229  0.160558
# 10                               Vacant Land   1199    6298  0.190378
#
#    Manhattan Wins
# 0           False
# 1           False
# 2            True
# 3           False
# 4           False
# ...

# %% [markdown]
# This table shows that there are more buildings of all types (except Multi-Family Elevator Buildings) in Brooklyn as compared to those in Manhattan. This result makes sense because Brooklyn is much larger in size compared to Manhattan.
